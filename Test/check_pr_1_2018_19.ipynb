# %%
from IPython.display import HTML

HTML('''
<script>code_show=true; 

function code_toggle() {
    if (code_show){
    $('div.input').hide();
    } else {
    $('div.input').show();
    }
    code_show = !code_show
} 

$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
''')
# Out:
# <script>code_show=true;
#
# function code_toggle() {
#     if (code_show){
#     $('div.input').hide();
#     } else {
#     $('div.input').show();
#     }
#     code_show = !code_show
# }
#
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Comprobación de la práctica 1

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %cd ..
# Out:
# /home/alex/Desktop/DALG/git

# %%
import string, random
import numpy as np
import pandas as pd
import sys

import networkx as nx

from sklearn.linear_model import LinearRegression

sys.path.append(r'D:\GoogleDriveBck\Cursos\DAA\practicas\2018_2019\python')
import grafos12 as gr
# Out:
# graph_from_matrix:
#
# ( 0 1 ) 10.0
# ( 0 2 ) 1.0
# ( 1 2 ) 1.0
# ( 2 3 ) 1.0
# ( 3 1 ) 1.0
#
# graph_from_dict:
#
# ( 0 1 ) 10
# ( 0 2 ) 1
# ( 1 2 ) 1
# ( 2 3 ) 1
# ( 3 1 ) 1
# {0: {1: 23.0, 2: 3.0}, 1: {3: 28.0}, 2: {3: 39.0, 4: 12.0}, 3: {0: 28.0, 1: 36.0, 2: 5.0}, 4: {0: 36.0, 3: 12.0}}
# graph_from_matrix:
#
# ( 0 1 ) 23.0
# ( 0 2 ) 3.0
# ( 1 3 ) 28.0
# ( 2 3 ) 39.0
# ( 2 4 ) 12.0
# ( 3 0 ) 28.0
# ( 3 1 ) 36.0
# ( 3 2 ) 5.0
# ( 4 0 ) 36.0
# ( 4 3 ) 12.0
#
# graph_from_dict:
#
# ( 0 1 ) 23.0
# ( 0 2 ) 3.0
# ( 1 3 ) 28.0
# ( 2 3 ) 39.0
# ( 2 4 ) 12.0
# ( 3 0 ) 28.0
# ( 3 1 ) 36.0
# ( 3 2 ) 5.0
# ( 4 0 ) 36.0
# ( 4 3 ) 12.0
#
# num_elem_iguales:	25
# 10
#
# true_sparse_factor: 0.750
# exp_sparse_factor:  0.751
#
# graph_from_dict:
#
# ( 0 1 ) 23.0
# ( 0 2 ) 3.0
# ( 1 3 ) 28.0
# ( 2 3 ) 39.0
# ( 2 4 ) 12.0
# ( 3 0 ) 28.0
# ( 3 1 ) 36.0
# ( 3 2 ) 5.0
# ( 4 0 ) 36.0
# ( 4 3 ) 12.0
#
# graph_from_dict:
#
# ( 0 1 ) 23.0
# ( 0 2 ) 3.0
# ( 1 3 ) 28.0
# ( 2 3 ) 39.0
# ( 2 4 ) 12.0
# ( 3 0 ) 28.0
# ( 3 1 ) 36.0
# ( 3 2 ) 5.0
# ( 4 0 ) 36.0
# ( 4 3 ) 12.0
# {0: inf, 1: 1, 2: 2, 3: 0}
#  {1: [3, 1], 2: [3, 1, 2], 3: [3]}
# NX:
# {1: 1, 2: 2, 3: 0}
#  {1: [3, 1], 2: [3, 1, 2], 3: [3]}
# Tiempo en Dijkstra dict
# Tiempo medio para n_nodes 10: 0.04644100000000018
# Tiempo medio para n_nodes 20: 0.14178099999999993
# Tiempo medio para n_nodes 30: 0.3351029999999997
# Tiempo medio para n_nodes 40: 0.639329
# Tiempo medio para n_nodes 50: 1.0918449999999997
# Tiempo medio para n_nodes 60: 1.6585239999999999
# Tiempo medio para n_nodes 70: 2.3664899999999998
# Tiempo medio para n_nodes 80: 3.3503510000000016
# Tiempo medio para n_nodes 90: 4.302503999999999
# Tiempo medio para n_nodes 100: 5.439855999999999
# Tiempo en Dijkstra dict
# Tiempo medio para n_nodes 10: 0.04230400000000145
# Tiempo medio para n_nodes 20: 0.21552499999999952
# Tiempo medio para n_nodes 30: 0.5101259999999996
# Tiempo medio para n_nodes 40: 0.9680570000000017
# Tiempo medio para n_nodes 50: 1.682257
# Tiempo medio para n_nodes 60: 2.4795049999999996
# Tiempo medio para n_nodes 70: 3.6098609999999987
# Tiempo medio para n_nodes 80: 4.899584999999998
# Tiempo medio para n_nodes 90: 6.456800000000001
# Tiempo medio para n_nodes 100: 8.274011999999999
# Tiempo en Dijkstra dict
# Tiempo medio para n_nodes 10: 0.05219499999999755
# Tiempo medio para n_nodes 20: 0.24426300000000367
# Tiempo medio para n_nodes 30: 0.614964999999998
# Tiempo medio para n_nodes 40: 1.2158909999999992
# Tiempo medio para n_nodes 50: 2.007997000000003
# Tiempo medio para n_nodes 60: 3.069499999999998
# Tiempo medio para n_nodes 70: 4.4037679999999995
# Tiempo medio para n_nodes 80: 6.034300999999999
# Tiempo medio para n_nodes 90: 7.959386999999992
# Tiempo medio para n_nodes 100: 10.424430000000001
# Tiempo en Dijkstra dict
# Tiempo medio para n_nodes 10: 0.06572900000000459
# Tiempo medio para n_nodes 20: 0.28507199999999955
# Tiempo medio para n_nodes 30: 0.6989319999999992
# Tiempo medio para n_nodes 40: 1.3673160000000024
# Tiempo medio para n_nodes 50: 2.288522999999998
# Tiempo medio para n_nodes 60: 3.508037999999999
# Tiempo medio para n_nodes 70: 5.0334880000000055
# Tiempo medio para n_nodes 80: 6.891902999999999
# Tiempo medio para n_nodes 90: 9.16280900000001
# Tiempo medio para n_nodes 100: 11.780795999999995
# Tiempo en Dijkstra dict
# Tiempo medio para n_nodes 10: 0.07182299999999486
# Tiempo medio para n_nodes 20: 0.32012900000000855
# Tiempo medio para n_nodes 30: 0.7771910000000162
# Tiempo medio para n_nodes 40: 1.5101629999999773
# Tiempo medio para n_nodes 50: 2.565499000000017
# Tiempo medio para n_nodes 60: 3.935573000000005
# Tiempo medio para n_nodes 70: 5.625427999999999
# Tiempo medio para n_nodes 80: 7.740142999999989
# Tiempo medio para n_nodes 90: 10.479246000000018
# Tiempo medio para n_nodes 100: 13.370394000000005
# ( 0 1 ) 10
# ( 0 2 ) 1
# ( 1 2 ) 1
# ( 2 3 ) 1
# ( 3 1 ) 1
#
# graph_from_dict:
#
# ( 0 1 ) 10
# ( 0 2 ) 1
# ( 1 2 ) 1
# ( 2 3 ) 1
# ( 3 1 ) 1
# Tiempo en Dijkstra NX
# Tiempo medio para n_nodes 10: 0.028274000000010346
# Tiempo medio para n_nodes 20: 0.08148599999998396
# Tiempo medio para n_nodes 30: 0.19737200000000144
# Tiempo medio para n_nodes 40: 0.38980699999999047
# Tiempo medio para n_nodes 50: 0.6133749999999907
# Tiempo medio para n_nodes 60: 0.9481530000000191
# Tiempo medio para n_nodes 70: 1.3567789999999889
# Tiempo medio para n_nodes 80: 1.8526820000000157
# Tiempo medio para n_nodes 90: 2.4605339999999956
# Tiempo medio para n_nodes 100: 3.209946000000002
# Tiempo en Dijkstra NX
# Tiempo medio para n_nodes 10: 0.026770999999996548
# Tiempo medio para n_nodes 20: 0.11417800000000966
# Tiempo medio para n_nodes 30: 0.3087419999999952
# Tiempo medio para n_nodes 40: 0.6017970000000048
# Tiempo medio para n_nodes 50: 1.0364979999999946
# Tiempo medio para n_nodes 60: 1.614861000000019
# Tiempo medio para n_nodes 70: 2.378926000000007
# Tiempo medio para n_nodes 80: 3.3602149999999824
# Tiempo medio para n_nodes 90: 4.562981000000008
# Tiempo medio para n_nodes 100: 6.101720999999998
# Tiempo en Dijkstra NX
# Tiempo medio para n_nodes 10: 0.03368599999998878
# Tiempo medio para n_nodes 20: 0.1463990000000024
# Tiempo medio para n_nodes 30: 0.40681200000000217
# Tiempo medio para n_nodes 40: 0.8107479999999896
# Tiempo medio para n_nodes 50: 1.4172840000000235
# Tiempo medio para n_nodes 60: 2.285665999999992
# Tiempo medio para n_nodes 70: 3.355115999999981
# Tiempo medio para n_nodes 80: 4.701620999999989
# Tiempo medio para n_nodes 90: 6.482612000000017
# Tiempo medio para n_nodes 100: 8.77374900000001
# Tiempo en Dijkstra NX
# Tiempo medio para n_nodes 10: 0.044136000000008835
# Tiempo medio para n_nodes 20: 0.18568499999997812
# Tiempo medio para n_nodes 30: 0.5560629999999946
# Tiempo medio para n_nodes 40: 1.0022209999999916
# Tiempo medio para n_nodes 50: 1.7745249999999828
# Tiempo medio para n_nodes 60: 2.8730170000000044
# Tiempo medio para n_nodes 70: 4.262133000000006
# Tiempo medio para n_nodes 80: 6.095551999999998
# Tiempo medio para n_nodes 90: 8.40158199999999
# Tiempo medio para n_nodes 100: 11.362303999999995
# Tiempo en Dijkstra NX
# Tiempo medio para n_nodes 10: 0.04975699999999961
# Tiempo medio para n_nodes 20: 0.25441000000000713
# Tiempo medio para n_nodes 30: 0.6516080000000102
# Tiempo medio para n_nodes 40: 1.2016209999999887
# Tiempo medio para n_nodes 50: 2.1813189999999736
# Tiempo medio para n_nodes 60: 3.4936739999999986
# Tiempo medio para n_nodes 70: 5.101511000000016
# Tiempo medio para n_nodes 80: 7.470860000000016
# Tiempo medio para n_nodes 90: 10.288442999999972
# Tiempo medio para n_nodes 100: 13.91501599999998
# Tiempo en Dijkstra NX
# Tiempo medio para n_nodes 1: 0.0005429999999932988
# Tiempo medio para n_nodes 2: 0.002579999999966276
# Tiempo medio para n_nodes 3: 0.00565199999999777
# Tiempo medio para n_nodes 4: 0.008709000000010292
# Tiempo medio para n_nodes 5: 0.011405000000024756
# Tiempo medio para n_nodes 6: 0.015272000000038588
# Tiempo medio para n_nodes 7: 0.020923999999979515
# Tiempo medio para n_nodes 8: 0.026768000000004122
# Tiempo medio para n_nodes 9: 0.03349900000000616
# Tiempo medio para n_nodes 10: 0.0413599999999974
# Tiempo medio para n_nodes 11: 0.0619310000000155
# Tiempo medio para n_nodes 12: 0.06309199999998327
# Tiempo medio para n_nodes 13: 0.07041499999996859
# Tiempo medio para n_nodes 14: 0.08537499999999909
# Tiempo medio para n_nodes 15: 0.09904099999999971
# Tiempo medio para n_nodes 16: 0.10805899999996882
# Tiempo medio para n_nodes 17: 0.1277149999999665
# Tiempo medio para n_nodes 18: 0.14510699999999588
# Tiempo medio para n_nodes 19: 0.15691900000001624
# Tiempo medio para n_nodes 20: 0.18614900000000034
# Tiempo medio para n_nodes 21: 0.19793700000002445
# Tiempo medio para n_nodes 22: 0.24393900000001167
# Tiempo medio para n_nodes 23: 0.26186799999999266
# Tiempo medio para n_nodes 24: 0.2899059999999736
# Tiempo medio para n_nodes 25: 0.30662699999999177
# Tiempo en Dijkstra NX
# Tiempo medio para n_nodes 1: 0.000551999999970576
# Tiempo medio para n_nodes 2: 0.003344000000026881
# Tiempo medio para n_nodes 3: 0.00703699999996843
# Tiempo medio para n_nodes 4: 0.011752000000001317
# Tiempo medio para n_nodes 5: 0.015890999999953692
# Tiempo medio para n_nodes 6: 0.02127500000000282
# Tiempo medio para n_nodes 7: 0.030490999999983615
# Tiempo medio para n_nodes 8: 0.03868399999998928
# Tiempo medio para n_nodes 9: 0.04936099999997623
# Tiempo medio para n_nodes 10: 0.0696839999999952
# Tiempo medio para n_nodes 11: 0.07598799999999528
# Tiempo medio para n_nodes 12: 0.09277600000001485
# Tiempo medio para n_nodes 13: 0.11919499999999061
# Tiempo medio para n_nodes 14: 0.1327609999999595
# Tiempo medio para n_nodes 15: 0.17383499999999685
# Tiempo medio para n_nodes 16: 0.17447300000003452
# Tiempo medio para n_nodes 17: 0.21072100000003502
# Tiempo medio para n_nodes 18: 0.2311109999999985
# Tiempo medio para n_nodes 19: 0.2696030000000178
# Tiempo medio para n_nodes 20: 0.3486130000000003
# Tiempo medio para n_nodes 21: 0.3451729999999884
# Tiempo medio para n_nodes 22: 0.37059600000003456
# Tiempo medio para n_nodes 23: 0.4084609999999884
# Tiempo medio para n_nodes 24: 0.45967200000001185
# Tiempo medio para n_nodes 25: 0.5364120000000412
# Tiempo en Dijkstra NX
# Tiempo medio para n_nodes 1: 0.0005429999999932988
# Tiempo medio para n_nodes 2: 0.0038970000000517757
# Tiempo medio para n_nodes 3: 0.007968000000005304
# Tiempo medio para n_nodes 4: 0.013756999999998243
# Tiempo medio para n_nodes 5: 0.019856000000004315
# Tiempo medio para n_nodes 6: 0.026890999999977794
# Tiempo medio para n_nodes 7: 0.03859800000003588
# Tiempo medio para n_nodes 8: 0.04952500000001692
# Tiempo medio para n_nodes 9: 0.06645799999995461
# Tiempo medio para n_nodes 10: 0.07890699999995832
# Tiempo medio para n_nodes 11: 0.09971699999999828
# Tiempo medio para n_nodes 12: 0.12210199999998395
# Tiempo medio para n_nodes 13: 0.14108199999998305
# Tiempo medio para n_nodes 14: 0.17239000000000715
# Tiempo medio para n_nodes 15: 0.1938299999999913
# Tiempo medio para n_nodes 16: 0.2253289999999879
# Tiempo medio para n_nodes 17: 0.266366000000005
# Tiempo medio para n_nodes 18: 0.29612900000000764
# Tiempo medio para n_nodes 19: 0.3309709999999768
# Tiempo medio para n_nodes 20: 0.3739610000000084
# Tiempo medio para n_nodes 21: 0.4224179999999933
# Tiempo medio para n_nodes 22: 0.47004600000002483
# Tiempo medio para n_nodes 23: 0.5202019999999834
# Tiempo medio para n_nodes 24: 0.5768360000000143
# Tiempo medio para n_nodes 25: 0.6453930000000128
# Tiempo en Dijkstra NX
# Tiempo medio para n_nodes 1: 0.0005229999999869506
# Tiempo medio para n_nodes 2: 0.004518000000018674
# Tiempo medio para n_nodes 3: 0.008370000000013533
# Tiempo medio para n_nodes 4: 0.014580000000023574
# Tiempo medio para n_nodes 5: 0.02413899999999103
# Tiempo medio para n_nodes 6: 0.0357150000000388
# Tiempo medio para n_nodes 7: 0.049452999999971325
# Tiempo medio para n_nodes 8: 0.06770999999997684
# Tiempo medio para n_nodes 9: 0.08701700000000301
# Tiempo medio para n_nodes 10: 0.10642199999995228
# Tiempo medio para n_nodes 11: 0.1205410000000029
# Tiempo medio para n_nodes 12: 0.14044699999999466
# Tiempo medio para n_nodes 13: 0.16972899999996116
# Tiempo medio para n_nodes 14: 0.19914399999998977
# Tiempo medio para n_nodes 15: 0.23735499999997955
# Tiempo medio para n_nodes 16: 0.26960399999995843
# Tiempo medio para n_nodes 17: 0.31302400000004127
# Tiempo medio para n_nodes 18: 0.3654459999999631
# Tiempo medio para n_nodes 19: 0.4105840000000285
# Tiempo medio para n_nodes 20: 0.4569439999999645
# Tiempo medio para n_nodes 21: 0.5192220000000134
# Tiempo medio para n_nodes 22: 0.5805039999999622
# Tiempo medio para n_nodes 23: 0.6449650000000133
# Tiempo medio para n_nodes 24: 0.7111229999999864
# Tiempo medio para n_nodes 25: 0.7934610000000362
# Tiempo en Dijkstra NX
# Tiempo medio para n_nodes 1: 0.0005299999999692773
# Tiempo medio para n_nodes 2: 0.004571999999996024
# Tiempo medio para n_nodes 3: 0.009201999999959298
# Tiempo medio para n_nodes 4: 0.01646099999999251
# Tiempo medio para n_nodes 5: 0.025963999999987664
# Tiempo medio para n_nodes 6: 0.03941700000001447
# Tiempo medio para n_nodes 7: 0.05516299999999319
# Tiempo medio para n_nodes 8: 0.07397199999996928
# Tiempo medio para n_nodes 9: 0.09707300000002306
# Tiempo medio para n_nodes 10: 0.12247500000000855
# Tiempo medio para n_nodes 11: 0.16375399999998308
# Tiempo medio para n_nodes 12: 0.1700050000000033
# Tiempo medio para n_nodes 13: 0.20044599999999946
# Tiempo medio para n_nodes 14: 0.23215199999998504
# Tiempo medio para n_nodes 15: 0.2841250000000173
# Tiempo medio para n_nodes 16: 0.32247999999998456
# Tiempo medio para n_nodes 17: 0.3675330000000372
# Tiempo medio para n_nodes 18: 0.41777700000000095
# Tiempo medio para n_nodes 19: 0.4928660000000491
# Tiempo medio para n_nodes 20: 0.5391689999999585
# Tiempo medio para n_nodes 21: 0.605241000000035
# Tiempo medio para n_nodes 22: 0.6868089999999825
# Tiempo medio para n_nodes 23: 0.757251999999994
# Tiempo medio para n_nodes 24: 0.8351240000000075
# Tiempo medio para n_nodes 25: 0.9109809999999925

# %% [markdown]
# # Basic Graph Functions

# %%
n_grafos = 10
n_nodes = 10 
sparse_factor = 0.37

print("\ncheck basic graph functions ....................")
print("\ncomprobamos la generación de grafos aleatorios ..........")
est_sp_f = gr.check_sparse_factor(n_grafos=n_grafos, n_nodes=n_nodes, sparse_factor=sparse_factor)
print("\n\testimated sp_f %5.2f sobre %d graphs with %d n_nodes and spars. fact. %5.2f" %  
      (est_sp_f, n_grafos, n_nodes, sparse_factor) )
# Out:
# check basic graph functions ....................
#
# comprobamos la generación de grafos aleatorios ..........
#
# 	estimated sp_f  0.36 sobre 10 graphs with 10 n_nodes and spars. fact.  0.37

# %% [markdown]
# # Writing to and Reading fromTGF Files

# %%
print("\ngeneramos grafo TFG ..........")
m_g = gr.rand_matr_pos_graph(n_nodes=5, sparse_factor=0.75, max_weight=10.)    

print("\ncomprobamos las funciones de conversión ..........")
print("\ngrafo inicial\n", m_g)

d_g = gr.m_g_2_d_g(m_g)
print("\nfrom m to d\n", d_g)

m_g2 = gr.d_g_2_m_g(d_g)
print("\nfrom d to m\n", m_g2)

print("\nguardamos grafo en archivo ..........")
gr.print_d_g(d_g)

f_name = 'my_graph.tfg'
gr.d_g_2_TGF(d_g, f_name)

print("\ny leemos grafo de archivo ..........")
d_g2 = gr.TGF_2_d_g(f_name)
gr.print_d_g(d_g2)
# Out:
# generamos grafo TFG ..........
#
# comprobamos las funciones de conversión ..........
#
# grafo inicial
#  [[ 0.  3.  5.  6.  9.]
#  [ 8.  0. inf  9. inf]
#  [ 5. inf  0. inf inf]
#  [ 1. inf  4.  0.  7.]
#  [ 1.  1.  9.  8.  0.]]
#
# from m to d
#  {0: {1: 3.0, 2: 5.0, 3: 6.0, 4: 9.0}, 1: {0: 8.0, 3: 9.0}, 2: {0: 5.0}, 3: {0: 1.0, 2: 4.0, 4: 7.0}, 4: {0: 1.0, 1: 1.0, 2: 9.0, 3: 8.0}}
# {0: {1: 3.0, 2: 5.0, 3: 6.0, 4: 9.0}, 1: {0: 8.0, 3: 9.0}, 2: {0: 5.0}, 3: {0: 1.0, 2: 4.0, 4: 7.0}, 4: {0: 1.0, 1: 1.0, 2: 9.0, 3: 8.0}}
#
# from d to m
#  [[ 0.  3.  5.  6.  9.]
#  [ 8.  0. inf  9. inf]
#  [ 5. inf  0. inf inf]
#  [ 1. inf  4.  0.  7.]
#  [ 1.  1.  9.  8.  0.]]
#
# guardamos grafo en archivo ..........
#
# graph_from_dict:
#
# ( 0 1 ) 3.0
# ( 0 2 ) 5.0
# ( 0 3 ) 6.0
# ( 0 4 ) 9.0
# ( 1 0 ) 8.0
# ( 1 3 ) 9.0
# ( 2 0 ) 5.0
# ( 3 0 ) 1.0
# ( 3 2 ) 4.0
# ( 3 4 ) 7.0
# ( 4 0 ) 1.0
# ( 4 1 ) 1.0
# ( 4 2 ) 9.0
# ( 4 3 ) 8.0
#
# y leemos grafo de archivo ..........
#
# graph_from_dict:
#
# ( 0 1 ) 3.0
# ( 0 2 ) 5.0
# ( 0 3 ) 6.0
# ( 0 4 ) 9.0
# ( 1 0 ) 8.0
# ( 1 3 ) 9.0
# ( 2 0 ) 5.0
# ( 3 0 ) 1.0
# ( 3 2 ) 4.0
# ( 3 4 ) 7.0
# ( 4 0 ) 1.0
# ( 4 1 ) 1.0
# ( 4 2 ) 9.0
# ( 4 3 ) 8.0

# %% [markdown]
# # Single Source Dijkstra

# %%
print("\nsingle source Dijkstra ....................")
print("\ncomprobamos la corrección de Dijkstra ..........")

print("\tgeneramos_grafo_aleatorio ..........")
m_g = gr.rand_matr_pos_graph(n_nodes=10, sparse_factor=0.75, max_weight=10.)    
d_g = gr.m_g_2_d_g(m_g)
nx_g = gr.d_g_2_nx_g(d_g)

l_difs = []
for u in d_g.keys():
    #print("\tcalculamos d y p mediante nuestro Dijkstra ..........")
    d, p = gr.dijkstra_d(d_g, u)
    
    #print("\ty mediante networkx ..........")
    d_n, p_n = nx.single_source_dijkstra(nx_g, u, weight='weight')
    
    print( "\n\tdistancias from %d:\n" % u,  d)
    print( "\n\tdistancias_nx from %d:\n" % u,  d_n)
    
    df   = pd.DataFrame.from_dict(d,   orient='index', columns=['dijks']).sort_index()
    df_n = pd.DataFrame.from_dict(d_n, orient='index', columns=['dijks']).sort_index()
    
    #l_difs: diferencias entre distancias Dijkstra y distancias con nx
    l_difs.append(abs(df['dijks'].values - df_n['dijks'].values).max())
# Out:
# single source Dijkstra ....................
#
# comprobamos la corrección de Dijkstra ..........
# 	generamos_grafo_aleatorio ..........
#
# 	distancias from 0:
#  {0: 0, 1: 5.0, 2: 4.0, 3: 5.0, 4: 1.0, 5: 1.0, 6: 2.0, 7: 4.0, 8: 4.0, 9: 4.0}
#
# 	distancias_nx from 0:
#  {0: 0, 1: 5.0, 2: 4.0, 3: 5.0, 4: 1.0, 5: 1.0, 6: 2.0, 7: 4.0, 8: 4.0, 9: 4.0}
#
# 	distancias from 1:
#  {0: 5.0, 1: 0, 2: 1.0, 3: 4.0, 4: 4.0, 5: 5.0, 6: 2.0, 7: 5.0, 8: 3.0, 9: 3.0}
#
# 	distancias_nx from 1:
#  {0: 5.0, 1: 0, 2: 1.0, 3: 4.0, 4: 4.0, 5: 5.0, 6: 2.0, 7: 5.0, 8: 3.0, 9: 3.0}
#
# 	distancias from 2:
#  {0: 4.0, 1: 4.0, 2: 0, 3: 8.0, 4: 4.0, 5: 4.0, 6: 1.0, 7: 8.0, 8: 7.0, 9: 7.0}
#
# 	distancias_nx from 2:
#  {0: 4.0, 1: 4.0, 2: 0, 3: 8.0, 4: 4.0, 5: 4.0, 6: 1.0, 7: 8.0, 8: 7.0, 9: 7.0}
#
# 	distancias from 3:
#  {0: 1.0, 1: 6.0, 2: 3.0, 3: 0, 4: 2.0, 5: 2.0, 6: 3.0, 7: 3.0, 8: 5.0, 9: 5.0}
#
# 	distancias_nx from 3:
#  {0: 1.0, 1: 6.0, 2: 3.0, 3: 0, 4: 2.0, 5: 2.0, 6: 3.0, 7: 3.0, 8: 5.0, 9: 5.0}
#
# 	distancias from 4:
#  {0: 4.0, 1: 8.0, 2: 8.0, 3: 8.0, 4: 0, 5: 5.0, 6: 5.0, 7: 7.0, 8: 8.0, 9: 7.0}
#
# 	distancias_nx from 4:
#  {0: 4.0, 1: 8.0, 2: 8.0, 3: 8.0, 4: 0, 5: 5.0, 6: 5.0, 7: 7.0, 8: 8.0, 9: 7.0}
#
# 	distancias from 5:
#  {0: 4.0, 1: 4.0, 2: 3.0, 3: 7.0, 4: 4.0, 5: 0, 6: 1.0, 7: 6.0, 8: 6.0, 9: 7.0}
#
# 	distancias_nx from 5:
#  {0: 4.0, 1: 4.0, 2: 3.0, 3: 7.0, 4: 4.0, 5: 0, 6: 1.0, 7: 6.0, 8: 6.0, 9: 7.0}
#
# 	distancias from 6:
#  {0: 3.0, 1: 3.0, 2: 4.0, 3: 7.0, 4: 3.0, 5: 4.0, 6: 0, 7: 7.0, 8: 6.0, 9: 6.0}
#
# 	distancias_nx from 6:
#  {0: 3.0, 1: 3.0, 2: 4.0, 3: 7.0, 4: 3.0, 5: 4.0, 6: 0, 7: 7.0, 8: 6.0, 9: 6.0}
#
# 	distancias from 7:
#  {0: 3.0, 1: 6.0, 2: 2.0, 3: 5.0, 4: 4.0, 5: 4.0, 6: 3.0, 7: 0, 8: 4.0, 9: 6.0}
#
# 	distancias_nx from 7:
#  {0: 3.0, 1: 6.0, 2: 2.0, 3: 5.0, 4: 4.0, 5: 4.0, 6: 3.0, 7: 0, 8: 4.0, 9: 6.0}
#
# 	distancias from 8:
#  {0: 2.0, 1: 6.0, 2: 4.0, 3: 1.0, 4: 3.0, 5: 2.0, 6: 3.0, 7: 4.0, 8: 0, 9: 2.0}
#
# 	distancias_nx from 8:
#  {0: 2.0, 1: 6.0, 2: 4.0, 3: 1.0, 4: 3.0, 5: 2.0, 6: 3.0, 7: 4.0, 8: 0, 9: 2.0}
#
# 	distancias from 9:
#  {0: 3.0, 1: 6.0, 2: 7.0, 3: 6.0, 4: 4.0, 5: 4.0, 6: 3.0, 7: 7.0, 8: 5.0, 9: 0}
#
# 	distancias_nx from 9:
#  {0: 3.0, 1: 6.0, 2: 7.0, 3: 6.0, 4: 4.0, 5: 4.0, 6: 3.0, 7: 7.0, 8: 5.0, 9: 0}

# %%
print("\ncomprobamos que todas las distancias son iguales ..........")
print("dif_dist", abs(np.array(l_difs)).max())
# Out:
# comprobamos que todas las distancias son iguales ..........
# dif_dist 0.0

# %%
mm = np.array([
[0, 1., 1., 1., np.inf, np.inf, np.inf],
[np.inf, 0., np.inf, 1., 1., np.inf, np.inf],
[np.inf, np.inf, 0., np.inf, np.inf, 1., np.inf],
[np.inf, np.inf, 1., 0., np.inf, 1., 1.],
[np.inf, np.inf, np.inf, 1., 0., np.inf, 1.],
[np.inf, np.inf, np.inf, np.inf, np.inf, 0., 1.],
[np.inf, np.inf, np.inf, np.inf, np.inf, np.inf, 0.]    
])

dd = gr.m_g_2_d_g(mm)
d, p = gr.dijkstra_d(dd, 0)
gr.min_paths(p)
# Out:
# {0: [0],
#  1: [0, 1],
#  2: [0, 2],
#  3: [0, 3],
#  4: [0, 1, 4],
#  5: [0, 2, 5],
#  6: [0, 3, 6]}

# %% [markdown]
# # Time Plotting and Fitting

# %%
n_graphs = 20
n_nodes_ini = 10 
n_nodes_fin = 50
step = 5
sparse_factor = 0.8

# %%
print("\najuste de tiempos dijkstra ....................")

l_t = gr.time_dijkstra_d(n_graphs, n_nodes_ini, n_nodes_fin, step, sparse_factor)
gr.fit_plot(l_t, gr.n2_log_n, size_ini=n_nodes_ini, size_fin=n_nodes_fin, step=step)    

l_t_nx = gr.time_dijkstra_nx(n_graphs, n_nodes_ini, n_nodes_fin, step, sparse_factor)
gr.fit_plot(l_t_nx, gr.n2_log_n, size_ini=n_nodes_ini, size_fin=n_nodes_fin, step=step)
# Out:
# ajuste de tiempos dijkstra ....................
# Tiempo en Dijkstra dict
# Tiempo medio para n_nodes 10: 0.07622099999997545
# Tiempo medio para n_nodes 15: 0.16764399999999569
# Tiempo medio para n_nodes 20: 0.3044779999999605
# Tiempo medio para n_nodes 25: 0.5227009999999837
# Tiempo medio para n_nodes 30: 0.7746070000000032
# Tiempo medio para n_nodes 35: 1.0915219999999977
# Tiempo medio para n_nodes 40: 1.4882400000000189
# Tiempo medio para n_nodes 45: 1.9455409999999915
# Tiempo medio para n_nodes 50: 2.470833999999968
# Tiempo en Dijkstra NX
# Tiempo medio para n_nodes 10: 0.04854100000000017
# Tiempo medio para n_nodes 15: 0.1083489999999756
# Tiempo medio para n_nodes 20: 0.22342200000002777
# Tiempo medio para n_nodes 25: 0.3671229999999923
# Tiempo medio para n_nodes 30: 0.5616759999999772
# Tiempo medio para n_nodes 35: 0.8572289999999612
# Tiempo medio para n_nodes 40: 1.126921999999979
# Tiempo medio para n_nodes 45: 1.5218470000000366
# Tiempo medio para n_nodes 50: 1.9860270000000355
